# %% [markdown]
# Pandas

# %%
import pandas as pd

# %%
a = [6,7,8]
dataset = pd.Series(a,index=["no.1","no.2","no.3"])
print(dataset)
# Out:
# no.1    6
# no.2    7
# no.3    8
# dtype: int64

# %%
data = {"name":["xx","yy","zz"],"color":["blue","green","red"]}
dataset= pd.DataFrame(data)
print(dataset)
# Out:
#   name  color
# 0   xx   blue
# 1   yy  green
# 2   zz    red

# %%
dataset = pd.read_csv("C:\\Users\\sanjai kumar s\\Downloads\\Data Analyst Coures\\dataset.csv")
dataset
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
print(dataset.shape) # number of rows and columns
# Out:
# (800, 12)

# %%
print(dataset.describe()) # The detail info about the dataset
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
print(dataset.columns) # TO get only the column names
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataset.loc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
dataset.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
dataset[dataset['HP']>50]
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 1      2                Ivysaur    Grass  Poison   60      62       63
# 2      3               Venusaur    Grass  Poison   80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison   80     100      123
# 5      5             Charmeleon     Fire     NaN   58      64       58
# 6      6              Charizard     Fire  Flying   78      84       78
# ..   ...                    ...      ...     ...  ...     ...      ...
# 793  717                Yveltal     Dark  Flying  126     131       95
# 794  718       Zygarde50% Forme   Dragon  Ground  108     100      121
# 797  720    HoopaHoopa Confined  Psychic   Ghost   80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark   80     160       60
# 799  721              Volcanion     Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1         80       80     60           1      False
# ...

# %%
dataset.sort_values(by='HP', ascending=True)
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 487  439   Mime Jr.  Psychic  Fairy   20      25       45       70       90
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
dataset.dropna()
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 6      6              Charizard     Fire  Flying  78      84       78
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dataset.fillna(0)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire       0  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dataset.duplicated()
# Out:
# Attack
# 49     False
# 62     False
# 82     False
# 100    False
# 52     False
#        ...
# 100    False
# 160    False
# 110    False
# 160    False
# 110    False
# Length: 800, dtype: bool

# %%
#inner join - only matching rows
#left - all the row from the left matching from right
#right - all the row from the right matching from left
#outer - all the rows from the both the sides

# %%
#merge() use to join row , concat() cell , and join() using index

# %%
pd.merge(dataset1,dataset2,on='HP',how='inner')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pd.merge(dataset1,dataset2,on='HP',how='inner')
#
# NameError: name 'dataset1' is not defined

# %%
dataset=pd.read_csv("C:\\Users\\sanjai kumar s\\Downloads\\Data Analyst Coures\\employee_data.csv")

# %%
dataset.head()
# Out:
#    EmployeeID     Name Department  Age   Salary JoiningDate Gender  Location
# 0         101    Alice         HR   29  50000.0  2015-06-01      F  New York
# 1         102      Bob         IT   35  70000.0  2013-04-21      M  San Jose
# 2         103  Charlie    Finance   30  65000.0  2016-03-12      M   Chicago
# 3         104    David         IT   40  85000.0  2011-11-30      M  New York
# 4         105      Eva         HR   28      NaN  2018-08-15      F   Chicago

# %%
dataset["JoiningDate"]=pd.to_datetime(dataset["JoiningDate"])
dataset["JoiningDate"].dt.year.value_counts()
# Out:
# JoiningDate
# 2015    2
# 2013    1
# 2016    1
# 2011    1
# 2018    1
# 2014    1
# 2017    1
# Name: count, dtype: int64

# %%
dataset[(dataset['Department'] == 'IT') & (dataset['Age'] > 30)]
# Out:
#    EmployeeID   Name Department  Age   Salary JoiningDate Gender  Location
# 1         102    Bob         IT   35  70000.0  2013-04-21      M  San Jose
# 3         104  David         IT   40  85000.0  2011-11-30      M  New York
# 6         107  Grace         IT   32  69000.0  2017-05-23      F  New York

# %%
Q1 = dataset['Salary'].quantile(0.25)  
Q3 = dataset['Salary'].quantile(0.75)  
IQR = Q3 - Q1  
df_outliers = dataset[(dataset['Salary'] < Q1 - 1.5 * IQR) | (dataset['Salary'] > Q3 + 1.5 * IQR)]

# %%
dataset.nlargest(2,"Salary")
# Out:
#    EmployeeID   Name Department  Age   Salary JoiningDate Gender  Location
# 3         104  David         IT   40  85000.0  2011-11-30      M  New York
# 5         106  Frank    Finance   38  72000.0  2014-07-19      M  San Jose

# %%
dataset[dataset['Location'].isin(["Newyork","San Jose"])]
# Out:
#    EmployeeID   Name Department  Age   Salary JoiningDate Gender  Location
# 1         102    Bob         IT   35  70000.0  2013-04-21      M  San Jose
# 5         106  Frank    Finance   38  72000.0  2014-07-19      M  San Jose

# %%
dataset['Department']
# Out:
# 0         HR
# 1         IT
# 2    Finance
# 3         IT
# 4         HR
# 5    Finance
# 6         IT
# 7         HR
# Name: Department, dtype: object

# %%
dataset["Department"].replace({"HR":"Human Resource"})
# Out:
# 0    Human Resource
# 1                IT
# 2           Finance
# 3                IT
# 4    Human Resource
# 5           Finance
# 6                IT
# 7    Human Resource
# Name: Department, dtype: object

# %%
dataset['Gender'].map({"M":"Male","F":"Female"})
# Out:
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# 5      Male
# 6    Female
# 7    Female
# Name: Gender, dtype: object

# %%
dataset.to_excel("output.xlsx",index=False)

# %%
dataset.to_csv("output.csv",index=False)

# %%
dataset['joiningdate']=pd.to_datetime(dataset['joiningddate'])
dataset['year']=dataset['joiningdate'].dt.year

# %%
to reshape the data and sumariszed with agreegation

# %%
pd.pivot_table(dataset,values='hours',index='internet',columns='marks',aggfunc='mean')
# Out:
# marks     68.57  69.27  70.05  70.06  70.11  70.20  70.27  70.34  70.40  \
# internet
# 0           NaN    NaN    NaN    NaN   5.01   5.14    NaN    5.4    NaN
# 1           5.2   5.07   5.09   5.45    NaN    NaN   5.28    NaN   5.22
#
# marks     70.51  ...  85.48  85.78  85.95  85.96  85.98  86.12  86.41  86.65  \
# internet         ...
# 0          5.22  ...    NaN   8.88   8.75    NaN   8.71   8.97    NaN    NaN
# 1           NaN  ...   8.69    NaN    NaN   8.93    NaN    NaN   8.92   8.93
#
# marks     86.75  86.99
# internet
# 0           NaN   8.66
# 1          8.94    NaN
#
# [2 rows x 188 columns]

# %%
#melt() - limited colums uncounable rows
#piovt() - limited rows uncounable columns

# %%
dataset.query("department=='IT' and age>30")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1015, in ChainMap.__getitem__(self, key)
#    1014         pass
# -> 1015 return self.__missing__(key)
#
# File c:\ProgramData\anaconda3\Lib\collections\__init__.py:1007, in ChainMap.__missing__(self, key)
#    1006 def __missing__(self, key):
# -> 1007     raise KeyError(key)
#
# KeyError: 'department'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dataset.groupby("HP")["Attack"].mean()
# Out:
# HP
# 1      90.000000
# 10     55.000000
# 20     23.333333
# 25     27.500000
# 28     25.000000
#          ...
# 165    75.000000
# 170    90.000000
# 190    33.000000
# 250     5.000000
# 255    10.000000
# Name: Attack, Length: 94, dtype: float64

# %%
dataset['HP'].apply(lambda x:x*1.1)
# Out:
# 0      49.5
# 1      66.0
# 2      88.0
# 3      88.0
# 4      42.9
#        ...
# 795    55.0
# 796    55.0
# 797    88.0
# 798    88.0
# 799    88.0
# Name: HP, Length: 800, dtype: float64

# %%
dataset.rename(columns={'HP': 'Hp'}, inplace=True)
print(dataset)
# Out:
#       #   Type 1  Type 2  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Hp
# 45    1    Grass  Poison      49       49       65       65     45
# 60    2    Grass  Poison      62       63       80       80     60
# 80    3    Grass  Poison      82       83      100      100     80
# 80    3    Grass  Poison     100      123      122      120     80
# 39    4     Fire     NaN      52       43       60       50     65
# ..  ...      ...     ...     ...      ...      ...      ...    ...
# 50  719     Rock   Fairy     100      150      100      150     50
# 50  719     Rock   Fairy     160      110      160      110    110
# 80  720  Psychic   Ghost     110       60      150      130     70
# 80  720  Psychic    Dark     160       60      170      130     80
# 80  721     Fire   Water     110      120      130       90     70
#
#     Generation  Legendary
# Hp
# 45           1      False
# 60           1      False
# 80           1      False
# 80           1      False
# ...

# %%
dataset.reset_index(drop=True)
# Out:
#        #   Type 1  Type 2  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      1    Grass  Poison      49       49       65       65     45
# 1      2    Grass  Poison      62       63       80       80     60
# 2      3    Grass  Poison      82       83      100      100     80
# 3      3    Grass  Poison     100      123      122      120     80
# 4      4     Fire     NaN      52       43       60       50     65
# ..   ...      ...     ...     ...      ...      ...      ...    ...
# 795  719     Rock   Fairy     100      150      100      150     50
# 796  719     Rock   Fairy     160      110      160      110    110
# 797  720  Psychic   Ghost     110       60      150      130     70
# 798  720  Psychic    Dark     160       60      170      130     80
# 799  721     Fire   Water     110      120      130       90     70
#
#      Generation  Legendary
# 0             1      False
# 1             1      False
# 2             1      False
# 3             1      False
# ...

# %%
dataset.set_index("Attack",inplace=True)
dataset
# Out:
#           #   Type 1  Type 2  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Attack
# 49        1    Grass  Poison       49       65       65     45           1
# 62        2    Grass  Poison       63       80       80     60           1
# 82        3    Grass  Poison       83      100      100     80           1
# 100       3    Grass  Poison      123      122      120     80           1
# 52        4     Fire     NaN       43       60       50     65           1
# ...     ...      ...     ...      ...      ...      ...    ...         ...
# 100     719     Rock   Fairy      150      100      150     50           6
# 160     719     Rock   Fairy      110      160      110    110           6
# 110     720  Psychic   Ghost       60      150      130     70           6
# 160     720  Psychic    Dark       60      170      130     80           6
# 110     721     Fire   Water      120      130       90     70           6
#
#         Legendary
# Attack
# 49          False
# ...

# %%
print(dataset['Name']) # TO get the values of a specific column
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(dataset[['Name', 'Speed']]) #To display Multiple titles
# Out:
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]

# %%
print(dataset.iloc[1]) # integer location accuires complete info about certain index (iloc-intgere location)
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
print(dataset.iloc[1:5]) #accuire complete info about range of index
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(dataset.iloc[1,2]) #accuire specific row data
# Out:
# Grass

# %%
for index,row in dataset.iterrows():
    print (index,row ["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
print(dataset.loc[dataset['Speed']>90])
# Out:
#        #                       Name  Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard    Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X    Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y    Fire  Flying   78     104       78
# 19    15      BeedrillMega Beedrill     Bug  Poison   65     150       40
# 22    18                    Pidgeot  Normal  Flying   83      80       75
# ..   ...                        ...     ...     ...  ...     ...      ...
# 791  715                    Noivern  Flying  Dragon   85      70       80
# 792  716                    Xerneas   Fairy     NaN  126     131       95
# 793  717                    Yveltal    Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme  Dragon  Ground  108     100      121
# 796  719        DiancieMega Diancie    Rock   Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
dataset.sort_values(["HP"],ascending=False) # Sorting by ascending order
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
dataset["Power"] = dataset["HP"] + dataset["Attack"] #Adding the new column
print(dataset.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Power
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
dataset = dataset.drop(columns=["Power"]) # removing the column
print(dataset.head())
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dataset.isna().any()
a = dataset["Speed"].fillna(dataset["Speed"].mean())
print(dataset)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import pandas as pd

# %%
dataset=pd.read_csv("C:\\Users\\sanjai kumar s\\Downloads\\sales_data.csv")

# %%
dataset.head()
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region  \
# 0        1  2024-01-05     Pen  Stationery        10      5   East
# 1        2  2024-01-07    Book  Stationery         5     20   West
# 2        3  2024-01-08     Bag        Bags         2     50   East
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North
# 4        5  2024-01-10  Marker  Stationery        12      3   East
#
#   Salesperson   QP   n
# 0        John   50  NA
# 1       Alice  100  NA
# 2         Bob  100  NA
# 3       Alice  105  NA
# 4        John   36  NA

# %%
dataset.tail()
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North       Alice
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob
# 6        7  2024-01-12     Bag        Bags         4     50  North       Alice
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John

# %%
print(dataset.shape)
# Out:
# (8, 8)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      8 non-null      int64
#  1   Date         8 non-null      object
#  2   Product      8 non-null      object
#  3   Category     8 non-null      object
#  4   Quantity     8 non-null      int64
#  5   Price        8 non-null      int64
#  6   Region       8 non-null      object
#  7   Salesperson  8 non-null      object
# dtypes: int64(3), object(5)
# memory usage: 644.0+ bytes

# %%
dataset.describe()
# Out:
#        OrderID   Quantity      Price
# count  8.00000   8.000000   8.000000
# mean   4.50000   7.625000  20.375000
# std    2.44949   4.373214  19.227491
# min    1.00000   2.000000   3.000000
# 25%    2.75000   4.750000   5.000000
# 50%    4.50000   6.500000  15.000000
# 75%    6.25000  10.500000  27.500000
# max    8.00000  15.000000  50.000000

# %%
dataset[dataset['Region']=='East']
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John

# %%
dataset[(dataset['Quantity']>5) & (dataset['Price']>10)]
# Out:
#    OrderID        Date Product   Category  Quantity  Price Region Salesperson
# 3        4  2024-01-09  Bottle  Drinkware         7     15  North       Alice
# 7        8  2024-01-13  Bottle  Drinkware         6     15   East        John

# %%
dataset.sort_values(by='Quantity', ascending=True)
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob
# 6        7  2024-01-12     Bag        Bags         4     50  North       Alice
# 1        2  2024-01-07    Book  Stationery         5     20   West       Alice
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North       Alice
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob

# %%
dataset.sort_values(by=['Quantity','Price'] , ascending=[False,True])
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North       Alice
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John
# 1        2  2024-01-07    Book  Stationery         5     20   West       Alice
# 6        7  2024-01-12     Bag        Bags         4     50  North       Alice
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob

# %%
dataset['QP']=dataset['Quantity']*dataset['Price']

dataset
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region  \
# 0        1  2024-01-05     Pen  Stationery        10      5   East
# 1        2  2024-01-07    Book  Stationery         5     20   West
# 2        3  2024-01-08     Bag        Bags         2     50   East
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North
# 4        5  2024-01-10  Marker  Stationery        12      3   East
# 5        6  2024-01-11     Pen  Stationery        15      5   West
# 6        7  2024-01-12     Bag        Bags         4     50  North
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East
#
#   Salesperson   QP
# 0        John   50
# 1       Alice  100
# 2         Bob  100
# 3       Alice  105
# 4        John   36
# 5         Bob   75
# 6       Alice  200
# 7        John   90

# %%
dataset.groupby('Region')['QP'].sum()
# Out:
# Region
# East     276
# North    305
# West     175
# Name: QP, dtype: int64

# %%
df=pd.read_csv("C:\\Users\\sanjai kumar s\\Downloads\\sales_data.csv")

# %%
df.head(3)
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 1        2  2024-01-07    Book  Stationery         5     20   West       Alice
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob

# %%
print(df.shape)
# Out:
# (8, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      8 non-null      int64
#  1   Date         8 non-null      object
#  2   Product      8 non-null      object
#  3   Category     8 non-null      object
#  4   Quantity     8 non-null      int64
#  5   Price        8 non-null      int64
#  6   Region       8 non-null      object
#  7   Salesperson  8 non-null      object
#  8   Revenue      8 non-null      int64
#  9   Discount     8 non-null      float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 772.0+ bytes

# %%
df["Product"]
# Out:
# 0       Pen
# 1      Book
# 2       Bag
# 3    Bottle
# 4    Marker
# 5       Pen
# 6       Bag
# 7    Bottle
# Name: Product, dtype: object

# %%
df[["Product","Quantity"]]
# Out:
#   Product  Quantity
# 0     Pen        10
# 1    Book         5
# 2     Bag         2
# 3  Bottle         7
# 4  Marker        12
# 5     Pen        15
# 6     Bag         4
# 7  Bottle         6

# %%
result = df.iloc[:2, :3]

print(result)
# Out:
#    OrderID        Date Product
# 0        1  2024-01-05     Pen
# 1        2  2024-01-07    Book

# %%
df[df['Region']=='East']
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John

# %%
df[df['Quantity']>10]
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob

# %%
df[(df['Category'] == 'Stationery') & (df['Price'] > 5)]
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region  \
# 1        2  2024-01-07    Book  Stationery         5     20   West
#
#   Salesperson  Revenue  Discount
# 1       Alice      100       1.0

# %%
df.sort_values(by='Quantity', ascending=False)
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North       Alice
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John
# 1        2  2024-01-07    Book  Stationery         5     20   West       Alice
# 6        7  2024-01-12     Bag        Bags         4     50  North       Alice
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob

# %%
df.sort_values(by=['Region','Price'], ascending=[True,False])
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region Salesperson
# 2        3  2024-01-08     Bag        Bags         2     50   East         Bob
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East        John
# 0        1  2024-01-05     Pen  Stationery        10      5   East        John
# 4        5  2024-01-10  Marker  Stationery        12      3   East        John
# 6        7  2024-01-12     Bag        Bags         4     50  North       Alice
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North       Alice
# 1        2  2024-01-07    Book  Stationery         5     20   West       Alice
# 5        6  2024-01-11     Pen  Stationery        15      5   West         Bob

# %%
df["Revenue"]=df["Quantity"]*df["Price"]
df
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region  \
# 0        1  2024-01-05     Pen  Stationery        10      5   East
# 1        2  2024-01-07    Book  Stationery         5     20   West
# 2        3  2024-01-08     Bag        Bags         2     50   East
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North
# 4        5  2024-01-10  Marker  Stationery        12      3   East
# 5        6  2024-01-11     Pen  Stationery        15      5   West
# 6        7  2024-01-12     Bag        Bags         4     50  North
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East
#
#   Salesperson  Revenue
# 0        John       50
# 1       Alice      100
# 2         Bob      100
# 3       Alice      105
# 4        John       36
# 5         Bob       75
# 6       Alice      200
# 7        John       90

# %%
df["Discount"]=df["Price"]*0.05

df
# Out:
#    OrderID        Date Product    Category  Quantity  Price Region  \
# 0        1  2024-01-05     Pen  Stationery        10      5   East
# 1        2  2024-01-07    Book  Stationery         5     20   West
# 2        3  2024-01-08     Bag        Bags         2     50   East
# 3        4  2024-01-09  Bottle   Drinkware         7     15  North
# 4        5  2024-01-10  Marker  Stationery        12      3   East
# 5        6  2024-01-11     Pen  Stationery        15      5   West
# 6        7  2024-01-12     Bag        Bags         4     50  North
# 7        8  2024-01-13  Bottle   Drinkware         6     15   East
#
#   Salesperson  Revenue  Discount
# 0        John       50      0.25
# 1       Alice      100      1.00
# 2         Bob      100      2.50
# 3       Alice      105      0.75
# 4        John       36      0.15
# 5         Bob       75      0.25
# 6       Alice      200      2.50
# 7        John       90      0.75

# %%
df.groupby('Region')['Revenue'].sum()
# Out:
# Region
# East     276
# North    305
# West     175
# Name: Revenue, dtype: int64

# %%
df.groupby("Salesperson")["Quantity"].mean()
# Out:
# Salesperson
# Alice    5.333333
# Bob      8.500000
# John     9.333333
# Name: Quantity, dtype: float64

# %%
df.groupby('Product')['Revenue'].max()
# Out:
# Product
# Bag       200
# Book      100
# Bottle    105
# Marker     36
# Pen        75
# Name: Revenue, dtype: int64

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df=pd.read_csv("C:\\Users\\sanjai kumar s\\Downloads\\sales_data.csv")

# %%
#distribution of frequency - histogram
#line plot - show trend  over time
#pie plot - show proportion 
#hexdibnplot - denstity of points
#area plot - show cumulate grow or total
#multiple chart - compare multiple plot in a one view
#bar plot - compare

# %%
import matplotlib.pyplot as plt

# %%
data=[11,22,33,44,55,66,77,88,99]
plt.hist(data,bins=5,color="tomato",edgecolor='black')
plt.title("histogram")
plt.xlabel("xx")
plt.ylabel("yy")
plt.show()

# %%
a=[12,23,34,45,56]
b=[67,78,89,91,10]
plt.plot(a,label="Product A",marker="o")
plt.plot(b,label="Product B",marker="s")
plt.title("Total number of days")
plt.show()

# %%
size=[5,8,2,6,4]
labels=['east','west','north','south','central']
plt.pie(size,labels=labels,autopct="%1.1f%%",startangle=90)
plt.title("pole")
# Out:
# Text(0.5, 1.0, 'pole')

# %%
a=[12,23,34,45,56]
b=[67,78,89,91,10]

plt.hexbin(a,b,gridsize=30,cmap="Blues")
plt.colorbar(label='count')
plt.title('xx')
# Out:
# Text(0.5, 1.0, 'xx')

# %%
import matplotlib.pyplot as plt

months = ['Mar', 'Jun', 'Jul', 'Aug', 'Sep']   
sales = [100, 150, 200, 250, 300]  

plt.fill_between(months, sales, color='pink', alpha=0.79)
plt.plot(months, sales, color='blue')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()
